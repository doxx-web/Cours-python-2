# %%
2+2
# Out:
# 4

# %%
str1 = "Bonjour"
str2 = "le monde"
str3 = str1 + " " + str2
print(str3)
# Out:
# Bonjour le monde

# %%
a= 5
b= 10
c= a + b
print(c)
# Out:
# 15

# %%
a= 5
if a%2 == 0:
    print("a est pair")
else:
    print("a est impair")
# Out:
# a est impair

# %%
import os, sys
os.path.dirname(os.path.abspath(__name__))
